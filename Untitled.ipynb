# %%
import pandas as pd

# %%
train=pd.read_csv('sales_train_v2.csv')

# %%
len(train['shop_id'].unique())
# Out:
# 60

# %%
train.sort_values(by=['date','shop_id','item_id'])
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 32569    01.01.2013               0        2      991       99.00
# 32552    01.01.2013               0        2     1472     2599.00
# 32632    01.01.2013               0        2     1905      249.00
# 32459    01.01.2013               0        2     2920      599.00
# 32504    01.01.2013               0        2     3320     1999.00
# 32865    01.01.2013               0        2     4464      599.00
# 32833    01.01.2013               0        2     4724     1399.00
# 32747    01.01.2013               0        2     5649     2190.00
# 32358    01.01.2013               0        2     6911      599.00
# 32099    01.01.2013               0        2     6916      999.50
# 32129    01.01.2013               0        2     8665      299.00
# 32130    01.01.2013               0        2     8712      198.00
# 31974    01.01.2013               0        2    11828     1699.00
# ...

# %%
test=pd.read_csv('test.csv')

# %%
test
# Out:
#             ID  shop_id  item_id
# 0            0        5     5037
# 1            1        5     5320
# 2            2        5     5233
# 3            3        5     5232
# 4            4        5     5268
# 5            5        5     5039
# 6            6        5     5041
# 7            7        5     5046
# 8            8        5     5319
# 9            9        5     5003
# 10          10        5     4806
# 11          11        5     4843
# 12          12        5     4607
# 13          13        5     4869
# 14          14        5     4870
# 15          15        5     4872
# 16          16        5     4874
# 17          17        5     4678
# 18          18        5     4892
# 19          19        5     4964
# 20          20        5     4717
# 21          21        5     5002
# 22          22        5     5823
# 23          23        5     5814
# 24          24        5     5900
# 25          25        5     5907
# 26          26        5     5908
# ...
